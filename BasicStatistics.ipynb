# %%
import pandas as pd
import numpy
import seaborn
import scipy

# %%
print("Versão Pandas: %s"  %pd.__version__)
print("Versão Numpy: %s"  %numpy.__version__)
print("Versão Seaborn: %s"  %seaborn.__version__)
print("Versão Scipy: %s"  %scipy.__version__)
# Out:
# Versão Pandas: 1.1.4
# Versão Numpy: 1.19.3
# Versão Seaborn: 0.11.2
# Versão Scipy: 1.8.1
